# %%
library(dplyr)
library(car)

# %%
dataset_url <- "https://raw.githubusercontent.com/wilkmzhou/STAT306_PROJECT_REPORT_2026/refs/heads/main/mercedes_benz_listings_cleaned.csv"

benzData <- read.csv(dataset_url)
head(benzData, n = 3)
# Out:
#   Vehicle_Name                         Year Vehicle_Age Model_Series Trim_Level
# 1 2025 Mercedes-Benz AMG S 63 E 4MATIC 2025 1           AMG S 63     S 63
# 2 2025 Mercedes-Benz GLE 580 4MATIC    2025 1           GLE          E 580
# 3 2025 Mercedes-Benz GLS 450 4MATIC    2025 1           GLS          S 450
#   Body_Type Is_AMG Is_4MATIC Mileage_Miles Mileage_Category Price_USD
# 1 Other     1      1          9860         Low (< 20K)      151900
# 2 SUV       0      1          3154         Low (< 20K)       82975
# 3 SUV       0      1         15496         Low (< 20K)       75500
#   Price_Category  Price_Per_Mile
# 1 Luxury (> $70K) 15.405680
# 2 Luxury (> $70K) 26.307863
# 3 Luxury (> $70K)  4.872225

# %%
benzData <- benzData |>
    na.omit() |>
    select(-Price_Per_Mile, -Price_Category, -Year, -Mileage_Category, -Vehicle_Name, -Model_Series, -Is_AMG)
head(benzData, n = 3)
# Out:
#   Vehicle_Age Trim_Level Body_Type Is_4MATIC Mileage_Miles Price_USD
# 1 1           S 63       Other     1          9860         151900
# 2 1           E 580      SUV       1          3154          82975
# 3 1           S 450      SUV       1         15496          75500

# %%
benzFit1 <- lm(Price_USD ~ ., data = benzData)
summary(benzFit1)
# Out:
# Call:
# lm(formula = Price_USD ~ ., data = benzData)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -20209  -2573      0   2358  20791
#
# Coefficients:
#                               Estimate Std. Error t value Pr(>|t|)
# (Intercept)                  6.515e+04  1.255e+04   5.193 1.94e-06 ***
# Vehicle_Age                 -1.595e+03  4.727e+02  -3.375  0.00121 **
# Trim_LevelAMG G 63           1.087e+05  1.003e+04  10.829  < 2e-16 ***
# Trim_LevelAMG GT 55          7.463e+04  1.572e+04   4.747 1.06e-05 ***
# Trim_LevelBase              -5.061e+03  1.193e+04  -0.424  0.67282
# Trim_LevelC 300             -9.789e+03  9.774e+03  -1.002  0.32002
# Trim_LevelC 43               1.540e+03  1.061e+04   0.145  0.88505
# Trim_LevelCLA 250           -1.588e+04  1.263e+04  -1.257  0.21281
# Trim_LevelE 250              2.415e+04  1.367e+04   1.767  0.08166 .
# Trim_LevelE 300             -9.528e+03  1.190e+04  -0.801  0.42603
# ...

# %%
plot(fitted(benzFit1), resid(benzFit1), xlab = "Fitted Values", ylab = "Residuals")
abline(0,0)
# Out:
# plot without title
